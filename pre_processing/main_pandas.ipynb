# %%
import pandas as pd

# %%
# create tabel1.create dictionary
data={
   "name":["a","b","c"] ,
   "age":[28,30,10]
}
df=pd.DataFrame(data)
df
# Out:
#   name  age
# 0    a   28
# 1    b   30
# 2    c   10

# %%
# read
df=pd.read_csv("./data.csv")
df
# Out:
#      name  age  salary
# 0   hasan   32    1000
# 1    reza   50     900
# 2   sahar   20     700
# 3    saba   18     500
# 4    hadi   40     800
# 5     ali   20     600
# 6  maryam   32     800

# %%
df.head()
# Out:
#     name  age  salary
# 0  hasan   32    1000
# 1   reza   50     900
# 2  sahar   20     700
# 3   saba   18     500
# 4   hadi   40     800

# %%
df.describe()
# Out:
#              age       salary
# count   7.000000     7.000000
# mean   30.285714   757.142857
# std    11.912379   171.824939
# min    18.000000   500.000000
# 25%    20.000000   650.000000
# 50%    32.000000   800.000000
# 75%    36.000000   850.000000
# max    50.000000  1000.000000

# %%
df["name"]
# Out:
# 0     hasan
# 1      reza
# 2     sahar
# 3      saba
# 4      hadi
# 5       ali
# 6    maryam
# Name: name, dtype: object

# %%
# کل سطر 2را نشان میدهد
df.iloc[2,:]
# Out:
# name      sahar
# age          20
# salary      700
# Name: 2, dtype: object

# %%
df.iloc[4,2]
# Out:
# np.int64(800)

# %%
# filter
filtered_df=df[df["salary"]>800]
filtered_df
# Out:
#     name  age  salary
# 0  hasan   32    1000
# 1   reza   50     900

# %%
# sort
df_sort=df.sort_values("salary",ascending=False)
df_sort
# Out:
#      name  age  salary
# 0   hasan   32    1000
# 1    reza   50     900
# 4    hadi   40     800
# 6  maryam   32     800
# 2   sahar   20     700
# 5     ali   20     600
# 3    saba   18     500

# %%
df
# Out:
#      name  age  salary
# 0   hasan   32    1000
# 1    reza   50     900
# 2   sahar   20     700
# 3    saba   18     500
# 4    hadi   40     800
# 5     ali   20     600
# 6  maryam   32     800

# %%
# subset
subset=df.loc[2:4,["age","salary"]]
subset
# Out:
#    age  salary
# 2   20     700
# 3   18     500
# 4   40     800

# %%
# group
df_grouped=df.groupby("age")
df_grouped

# %%
df_grouped.count()
# Out:
#      name  salary
# age
# 18      1       1
# 20      2       2
# 32      2       2
# 40      1       1
# 50      1       1

# %%
# add new column
df["test"]=[10,20,30,40,50,60,70]
df
# Out:
#      name  age  salary  test
# 0   hasan   32    1000    10
# 1    reza   50     900    20
# 2   sahar   20     700    30
# 3    saba   18     500    40
# 4    hadi   40     800    50
# 5     ali   20     600    60
# 6  maryam   32     800    70

# %%
# remove a column
df.drop("test",axis=1,inplace=True)
df
# Out:
#      name  age  salary
# 0   hasan   32    1000
# 1    reza   50     900
# 2   sahar   20     700
# 3    saba   18     500
# 4    hadi   40     800
# 5     ali   20     600
# 6  maryam   32     800

# %%
len(df)
# Out:
# 7

# %%
# add a new row
df.loc[len(df)]={
    "name":"test",
    "age":20
}
df
# Out:
#      name  age  salary
# 0   hasan   32  1000.0
# 1    reza   50   900.0
# 2   sahar   20   700.0
# 3    saba   18   500.0
# 4    hadi   40   800.0
# 5     ali   20   600.0
# 6  maryam   32   800.0
# 7    test   20     NaN

# %%
# find all nan
df.isna()
# Out:
#     name    age  salary
# 0  False  False   False
# 1  False  False   False
# 2  False  False   False
# 3  False  False   False
# 4  False  False   False
# 5  False  False   False
# 6  False  False   False
# 7  False  False    True

# %%
# delet nan
df.dropna()
# Out:
#      name  age  salary
# 0   hasan   32  1000.0
# 1    reza   50   900.0
# 2   sahar   20   700.0
# 3    saba   18   500.0
# 4    hadi   40   800.0
# 5     ali   20   600.0
# 6  maryam   32   800.0

# %%
df.isna()
# Out:
#     name    age  salary
# 0  False  False   False
# 1  False  False   False
# 2  False  False   False
# 3  False  False   False
# 4  False  False   False
# 5  False  False   False
# 6  False  False   False
# 7  False  False    True

# %%
df.dropna()
# Out:
#      name  age  salary
# 0   hasan   32  1000.0
# 1    reza   50   900.0
# 2   sahar   20   700.0
# 3    saba   18   500.0
# 4    hadi   40   800.0
# 5     ali   20   600.0
# 6  maryam   32   800.0

# %%
df.isna()
# Out:
#     name    age  salary
# 0  False  False   False
# 1  False  False   False
# 2  False  False   False
# 3  False  False   False
# 4  False  False   False
# 5  False  False   False
# 6  False  False   False
# 7  False  False    True

# %%
df2=df.fillna(0)
df2
# Out:
#      name  age  salary
# 0   hasan   32  1000.0
# 1    reza   50   900.0
# 2   sahar   20   700.0
# 3    saba   18   500.0
# 4    hadi   40   800.0
# 5     ali   20   600.0
# 6  maryam   32   800.0
# 7    test   20     0.0

# %%
df.to_csv("new data.csv")

# %%
df
# Out:
#      name  age  salary
# 0   hasan   32  1000.0
# 1    reza   50   900.0
# 2   sahar   20   700.0
# 3    saba   18   500.0
# 4    hadi   40   800.0
# 5     ali   20   600.0
# 6  maryam   32   800.0
# 7    test   20     NaN
