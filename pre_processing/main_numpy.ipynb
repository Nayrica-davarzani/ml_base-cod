# %%
import numpy as np

# %%
a=np.array([1,2,3,4])
a
# Out:
# array([1, 2, 3, 4])

# %% [markdown]
# matrix

# %%
b= np.array([[1,2],[3,4]])
b
# Out:
# array([[1, 2],
#        [3, 4]])

# %% [markdown]
# shape

# %%
print(a.shape,b.shape)
# Out:
# (4,) (2, 2)

# %%
# reshape
c=a.reshape((4,1))
c
# Out:
# array([[1],
#        [2],
#        [3],
#        [4]])

# %%
c.shape
# Out:
# (4, 1)

# %%
a.shape
# Out:
# (4,)

# %%
# ضرب اعداد باید با تعداد المان های آن برابر باشد گثلا آن 4المان دارد 
d=a.reshape((2,2,1))
d.shape
# Out:
# (2, 2, 1)

# %%
# زمانی که نمیدانید
d=a.reshape((2,-1,2))
d.shape
# Out:
# (2, 1, 2)

# %%
# concatination
a=np.array([1,2,3])
b=np.array([3,4,5])
c=np.concatenate((a,b))
c
# Out:
# array([1, 2, 3, 3, 4, 5])

# %%
a=np.array([1,2,3])
b=np.array([3,4,5])
c=a+b
c
# Out:
# array([4, 6, 8])

# %%
a=np.array([1,2,3])
b=np.array([3,4,5])
c=a*b
c
# Out:
# array([ 3,  8, 15])

# %%
# broadcasting
c= np.array([10])
d=a+c
d
# Out:
# array([11, 12, 13])

# %%
e=b+5
e
# Out:
# array([ 8,  9, 10])

# %%
a=np.array([1,2,3,4,5,6,7,8])
a.shape
# Out:
# (8,)

# %%
# slice
b=a[2:7]
b
# Out:
# array([3, 4, 5, 6, 7])

# %%
b=a[2:7:2]
b
# Out:
# array([3, 5, 7])

# %%
c=a[a>3]
c
# Out:
# array([4, 5, 6, 7, 8])

# %%
a
# Out:
# array([1, 2, 3, 4, 5, 6, 7, 8])

# %%
# مجموع تمام المان های بردار
sum_a=np.sum(a)
sum_a
# Out:
# np.int64(36)

# %%
max_a=np.max(a)
max_a
# Out:
# np.int64(8)

# %%
min_a=np.min(a)
min_a
# Out:
# np.int64(1)

# %%
# sort data
a=np.array([4,2,9,6,7,3,5])
b=np.sort(a)
b
# Out:
# array([2, 3, 4, 5, 6, 7, 9])

# %%
# create random matix 
# (3,4)ابعاد
a=np.random.randint(0,10,(3,4))
a
# Out:
# array([[4, 3, 6, 7],
#        [8, 5, 6, 3],
#        [0, 6, 9, 2]], dtype=int32)

# %%
# vstack عمودی

# first array in first row and other in the second row
a= np.array([1,2,3])
b=np.array([4,5,6])
c=np.vstack((a,b))
c
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
c.shape
# Out:
# (3, 3)

# %%
# hstack list(tuple)افقی
a= np.array([1,2,3])
b=np.array([4,5,6])
c=np.hstack((a,b))
c
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
# normalize:میانگین به سمت صفر و انحراف معیار به سمت 1 برود
#   1.mean2.std(انحراف معیار)3.norm_a= (a-mean_a)/std_a4.np.mean(norm_a)5.np.std(norm_a)


a
# Out:
# array([1, 2, 3])

# %%
mean_a=np.mean(a)
mean_a
# Out:
# np.float64(2.0)

# %%
std_a=np.std(a)
std_a
# Out:
# np.float64(0.816496580927726)

# %%
norm_a= (a-mean_a)/std_a
norm_a
# Out:
# array([-1.22474487,  0.        ,  1.22474487])

# %%
np.mean(norm_a)
# Out:
# np.float64(0.0)

# %%
np.std(norm_a)
# Out:
# np.float64(0.9999999999999999)
